# %%
import os
from collections import defaultdict
import pandas as pd
import time
from google import genai
from google.genai import types
from tqdm import tqdm
import csv

# %%
# Set up the API client
client = genai.Client(api_key="")

# Set the parent directory containing subfolders
parent_dir = "/Users/aryanrastogi/college/vr/vr_major/categorized_data"

# %%
# Valid image extensions
image_extensions = {'.jpg', '.jpeg', '.png', '.webp'}

# Dictionary to store folder and image count
folder_image_counts = defaultdict(int)

# Count images in each subfolder
for subfolder in os.listdir(parent_dir):
    subfolder_path = os.path.join(parent_dir, subfolder)
    if os.path.isdir(subfolder_path):
        count = sum(
            1 for f in os.listdir(subfolder_path)
            if os.path.splitext(f)[1].lower() in image_extensions
        )
        folder_image_counts[subfolder] = count

# Sort folders by image count (descending)
sorted_folders = sorted(folder_image_counts.items(), key=lambda x: x[1], reverse=True)

# Display results
print("Subfolders sorted by number of images:")
for folder, count in sorted_folders:
    print(f"{folder}: {count} images")
# Out:
# Subfolders sorted by number of images:
# CELLULAR_PHONE_CASE: 63996 images
# GROCERY: 3998 images
# SHOES: 3129 images
# HOME: 2513 images
# CHAIR: 1717 images
# HOME_FURNITURE_AND_DECOR: 1436 images
# HOME_BED_AND_BATH: 1325 images
# FINENECKLACEBRACELETANKLET: 1120 images
# SOFA: 1000 images
# HEALTH_PERSONAL_CARE: 969 images
# FINEEARRING: 915 images
# OFFICE_PRODUCTS: 857 images
# TABLE: 837 images
# PET_SUPPLIES: 815 images
# ACCESSORY: 755 images
# HANDBAG: 747 images
# KITCHEN: 654 images
# SPORTING_GOODS: 647 images
# HARDWARE_HANDLE: 625 images
# EARRING: 613 images
# RUG: 591 images
# LAMP: 543 images
# LIGHT_BULB: 540 images
# OUTDOOR_LIVING: 505 images
# LIGHT_FIXTURE: 503 images
# FINERING: 453 images
# NECKLACE: 431 images
# JANITORIAL_SUPPLY: 407 images
# SUITCASE: 390 images
# HAT: 352 images
# TOOLS: 349 images
# STOOL_SEATING: 344 images
# OTTOMAN: 330 images
# BEAUTY: 320 images
# PORTABLE_ELECTRONIC_DEVICE_COVER: 310 images
# FOOD_SERVICE_SUPPLY: 271 images
# SHELF: 261 images
# DRINKING_CUP: 257 images
# PLANTER: 248 images
# AUTO_ACCESSORY: 236 images
# NUTRITIONAL_SUPPLEMENT: 234 images
# STORAGE_HOOK: 225 images
# SAFETY_SUPPLY: 217 images
# CABINET: 216 images
# BACKPACK: 216 images
# BABY_PRODUCT: 201 images
# WIRELESS_ACCESSORY: 187 images
# LUGGAGE: 184 images
# BATTERY: 181 images
# PILLOW: 177 images
# WALL_ART: 169 images
# SKIN_CLEANING_AGENT: 166 images
# WALLET: 165 images
# HARDWARE: 163 images
# DESK: 162 images
# VITAMIN: 152 images
# COFFEE: 152 images
# COMPUTER_ADD_ON: 151 images
# JAR: 149 images
# INSTRUMENT_PARTS_AND_ACCESSORIES: 149 images
# SAUTE_FRY_PAN: 147 images
# SCREEN_PROTECTOR: 142 images
# FLAT_SCREEN_DISPLAY_MOUNT: 136 images
# CHARGING_ADAPTER: 130 images
# HERB: 128 images
# BISS: 128 images
# BOOT: 125 images
# ABIS_DRUGSTORE: 123 images
# CLOCK: 123 images
# RING: 122 images
# FURNITURE_COVER: 121 images
# ACCESSORY_OR_PART_OR_SUPPLY: 121 images
# SKIN_MOISTURIZER: 120 images
# HEADPHONES: 118 images
# FILE_FOLDER: 118 images
# BRACELET: 115 images
# DAIRY_BASED_DRINK: 114 images
# RECREATION_BALL: 112 images
# STORAGE_BAG: 112 images
# PLUMBING_FIXTURE: 111 images
# WRITING_INSTRUMENT: 111 images
# ELECTRONIC_ADAPTER: 110 images
# THERMOPLASTIC_FILAMENT: 105 images
# WASTE_BAG: 103 images
# CLEANING_AGENT: 103 images
# CLOTHES_HANGER: 101 images
# TOWEL_HOLDER: 100 images
# FINEOTHER: 99 images
# COMPUTER_COMPONENT: 98 images
# SANDAL: 98 images
# BREAD: 94 images
# UMBRELLA: 93 images
# FLAT_SHEET: 93 images
# DRESSER: 92 images
# MEDICATION: 92 images
# HOME_MIRROR: 91 images
# MAJOR_HOME_APPLIANCES: 89 images
# HOME_LIGHTING_AND_LAMPS: 88 images
# TEA: 88 images
# BENCH: 87 images
# PANTRY: 86 images
# FURNITURE: 86 images
# LABEL: 85 images
# OFFICE_ELECTRONICS: 85 images
# DAIRY_BASED_CHEESE: 83 images
# SPEAKERS: 82 images
# STORAGE_BOX: 81 images
# BASKET: 79 images
# LEGUME: 78 images
# ELECTRIC_FAN: 77 images
# LOCK: 76 images
# FLATWARE: 76 images
# STORAGE_BINDER: 74 images
# WINE: 74 images
# WRENCH: 72 images
# STRING_LIGHT: 71 images
# HEADBOARD: 71 images
# DISHWARE_PLACE_SETTING: 69 images
# TOILET_PAPER_HOLDER: 68 images
# CLOTHES_RACK: 68 images
# TEACHING_EQUIPMENT: 67 images
# MECHANICAL_COMPONENTS: 66 images
# PROTEIN_SUPPLEMENT_POWDER: 65 images
# BED: 64 images
# EXERCISE_MAT: 64 images
# FAUCET: 64 images
# VEGETABLE: 62 images
# POWER_SUPPLIES_OR_PROTECTION: 62 images
# SWATCH: 61 images
# COSMETIC_CASE: 61 images
# DUTCH_OVENS: 61 images
# PAPER_PRODUCT: 60 images
# PROFESSIONAL_HEALTHCARE: 60 images
# ABIS_LAWN_AND_GARDEN: 60 images
# WRITING_BOARD: 58 images
# LAUNDRY_HAMPER: 55 images
# MUSCLE_ROLLER: 55 images
# BED_FRAME: 55 images
# SAUCE: 55 images
# DRYING_RACK: 54 images
# BOTTLE: 54 images
# VASE: 53 images
# SKIN_CLEANING_WIPE: 53 images
# CARGO_STRAP: 53 images
# EDIBLE_OIL_VEGETABLE: 51 images
# FRUIT: 50 images
# PRINT_COPY_PAPER: 49 images
# ENVELOPE: 49 images
# LAUNDRY_DETERGENT: 49 images
# KEYBOARDS: 48 images
# HOME_LIGHTING_ACCESSORY: 48 images
# LIP_COLOR: 47 images
# COOKIE: 46 images
# PORTABLE_ELECTRONIC_DEVICE_STAND: 46 images
# BODY_POSITIONER: 46 images
# SECURITY_ELECTRONICS: 45 images
# SAFE: 44 images
# EYEWEAR: 44 images
# HERBAL_SUPPLEMENT: 44 images
# SHAMPOO: 44 images
# INPUT_MOUSE: 43 images
# TOTE_BAG: 42 images
# OUTDOOR_RECREATION_PRODUCT: 40 images
# PHONE_ACCESSORY: 40 images
# FASHIONNECKLACEBRACELETANKLET: 40 images
# CAMERA_OTHER_ACCESSORIES: 38 images
# ABIS_BEAUTY: 37 images
# TOY_FIGURE: 37 images
# AREA_DEODORIZER: 37 images
# AUTO_PART: 36 images
# BEAN_BAG_CHAIR: 36 images
# SUNSCREEN: 35 images
# COSMETIC_BRUSH: 35 images
# EARMUFF: 34 images
# STICKER_DECAL: 34 images
# FOOD_BLENDER: 33 images
# NOODLE: 33 images
# CANDLE: 32 images
# TRASH_CAN: 32 images
# FACIAL_TISSUE: 32 images
# PORTABLE_ELECTRONIC_DEVICE_MOUNT: 32 images
# FASHIONEARRING: 31 images
# AUTO_OIL: 31 images
# MOUTHWASH: 31 images
# COMPUTER_DRIVE_OR_STORAGE: 31 images
# CAKE: 31 images
# CLEANING_BRUSH: 30 images
# SCREWDRIVER: 30 images
# MARKING_PEN: 30 images
# CAMERA_BAGS_AND_CASES: 30 images
# CONDITIONER: 30 images
# DISHWARE_PLATE: 29 images
# FASHIONRING: 29 images
# CAMERA_TRIPOD: 29 images
# VIDEO_GAME_ACCESSORIES: 29 images
# MICROPHONE: 28 images
# CE_ACCESSORY: 28 images
# FASHIONOTHER: 28 images
# BREAKFAST_CEREAL: 27 images
# ORTHOPEDIC_BRACE: 27 images
# JEWELRY_STORAGE: 27 images
# PACKAGED_SOUP_AND_STEW: 26 images
# DRINK_FLAVORED: 26 images
# CARRYING_CASE_OR_BAG: 26 images
# DISHWARE_BOWL: 26 images
# POWER_STRIP: 25 images
# JEWELRY_SET: 25 images
# MINERAL_SUPPLEMENT: 25 images
# SNACK_MIX: 25 images
# BAKING_PAN: 25 images
# DRILL_BITS: 25 images
# STAPLER: 24 images
# SNACK_CHIP_AND_CRISP: 24 images
# DAIRY_BASED_ICE_CREAM: 24 images
# CONSUMER_ELECTRONICS: 23 images
# PLACEMAT: 23 images
# MULTIPORT_HUB: 23 images
# FREESTANDING_SHELTER: 23 images
# SHOE_INSERT: 23 images
# SNACK_FOOD_BAR: 23 images
# FLASH_MEMORY: 23 images
# WATER_PURIFICATION_UNIT: 23 images
# POULTRY: 23 images
# SALAD_DRESSING: 22 images
# MEAL_HOLDER: 22 images
# SUGAR: 22 images
# WATER: 22 images
# ABIS_KITCHEN: 22 images
# PERSONAL_CARE_APPLIANCE: 21 images
# STORAGE_DRAWER: 21 images
# PORTABLE_AUDIO: 21 images
# EXERCISE_BAND: 21 images
# KITCHEN_KNIFE: 21 images
# FOOD_STORAGE_BAG: 21 images
# SAFETY_GLASSES: 21 images
# HUMIDIFIER: 21 images
# INK_OR_TONER: 21 images
# CHOCOLATE_CANDY: 20 images
# DAIRY_BASED_CREAM: 20 images
# CAMERA_LENS_FILTERS: 20 images
# AIR_CONDITIONER: 20 images
# NUT_BUTTER: 20 images
# PERSONAL_COMPUTER: 20 images
# SCISSORS: 20 images
# COFFEE_MAKER: 19 images
# PUMP_DISPENSER: 19 images
# BUCKET: 19 images
# STORAGE_RACK: 19 images
# ELECTRIC_WATER_BOILER: 19 images
# SHOWERHEAD: 18 images
# DOORSTOP: 18 images
# WATCH: 18 images
# PLIERS: 18 images
# VACUUM_CLEANER: 17 images
# WOUND_DRESSING: 17 images
# INKJET_PRINTER_INK: 17 images
# JUICE_AND_JUICE_DRINK: 17 images
# SOUND_AND_RECORDING_EQUIPMENT: 17 images
# SUNGLASSES: 16 images
# DISHWASHER_DETERGENT: 16 images
# FRUIT_SNACK: 16 images
# BOTTLE_RACK: 16 images
# INCENSE: 16 images
# EYELID_COLOR: 16 images
# WHEEL: 16 images
# CRACKER: 16 images
# BROOM: 16 images
# CE_CARRYING_CASE_OR_BAG: 16 images
# BATHWATER_ADDITIVE: 15 images
# MEAT: 15 images
# TOYS_AND_GAMES: 15 images
# WILDLIFE_FEEDER: 15 images
# FOOD_SLICER: 15 images
# TOILET_SEAT: 15 images
# BLANK_MEDIA: 15 images
# VEHICLE_SEAT_COVER: 15 images
# ANTENNA: 15 images
# MILK_SUBSTITUTE: 15 images
# TOASTER: 14 images
# WINDOW_SHADE: 14 images
# LIGHT_SOURCE: 14 images
# BAG: 14 images
# COMPUTER_INPUT_DEVICE: 14 images
# POPCORN: 13 images
# LADDER: 13 images
# SEALS: 13 images
# CARD_STOCK: 13 images
# PITCHER: 13 images
# ABIS_ELECTRONICS: 13 images
# PAPER_TOWEL_HOLDER: 12 images
# CANDLE_HOLDER: 12 images
# MOUSE_PAD: 12 images
# AV_FURNITURE: 12 images
# SHIPPING_BOX: 12 images
# TOY_SLIME: 12 images
# ELECTROMECHANICAL_GAUGE: 12 images
# TOOTHBRUSH: 12 images
# ABIS_HOME_IMPROVEMENT: 12 images
# POT_HOLDER: 11 images
# FIRST_AID_KIT: 11 images
# NUTS: 11 images
# UTILITY_KNIFE: 11 images
# PASTRY: 11 images
# WEIGH_SCALE: 11 images
# CASSEROLES: 11 images
# VIDEO_PROJECTOR: 11 images
# RAZOR_BLADE_CARTRIDGE: 11 images
# WATER_PUMP: 10 images
# VINEGAR: 10 images
# HONEY: 10 images
# CHARM: 10 images
# INPUT_PEN: 10 images
# HARDWARE_HINGE: 10 images
# PORTABLE_AV_DEVICE: 10 images
# CANDY: 10 images
# SPIRITS: 9 images
# ESSENTIAL_OIL: 9 images
# FLOUR: 9 images
# WASHER_DRYER_COMBINATION: 9 images
# WATER_FLOTATION_DEVICE: 9 images
# SWEATBAND: 9 images
# BUILDING_MATERIAL: 9 images
# RICE_COOKERS: 9 images
# LEOTARD: 9 images
# EDUCATIONAL_SUPPLIES: 9 images
# STEERING_WHEEL_COVER: 9 images
# HAIR_COMB: 9 images
# THERMOS: 9 images
# ART_AND_CRAFT_SUPPLY: 9 images
# STATIONARY_BICYCLE: 9 images
# COMPUTER: 9 images
# FISH: 9 images
# FOOD_MIXER: 8 images
# PET_PEST_CONTROL: 8 images
# ASTRINGENT_SUBSTANCE: 8 images
# LAB_SUPPLY: 8 images
# STRINGED_INSTRUMENTS: 8 images
# HARDWARE_TUBING: 8 images
# BODY_DEODORANT: 8 images
# FOOD_PROCESSOR: 8 images
# MULTITOOL: 8 images
# PERSONAL_PILL_DISPENSER: 8 images
# HAIR_REMOVAL_AGENT: 8 images
# MICROSCOPES: 8 images
# PRETZEL: 8 images
# CAN_OPENER: 8 images
# PRESSURE_COOKER: 7 images
# BARBELL: 7 images
# REMOTE_CONTROL: 7 images
# NAIL_POLISH: 7 images
# LICENSE_PLATE_ATTACHMENT: 7 images
# SELF_STICK_NOTE: 7 images
# HAIR_CLEANER_CONDITIONER: 7 images
# CAMCORDER: 7 images
# ELECTRONIC_CABLE: 7 images
# CAR_ELECTRONICS: 7 images
# BOOKEND: 7 images
# CAMERA_SUPPORT: 7 images
# HAIR_STYLING_AGENT: 7 images
# BARBECUE_GRILL: 7 images
# VEHICLE_INTERIOR_SHADE: 7 images
# MICROWAVE_OVEN: 7 images
# FOOD_PREPARATION_MOLD: 7 images
# FOUNTAIN: 6 images
# RADIO: 6 images
# BAKING_MIX: 6 images
# COUNTERTOP_GRIDDLE_APPLIANCE: 6 images
# VALVE: 6 images
# PACIFIER: 6 images
# ANIMAL_LITTER: 6 images
# AUTO_CHEMICAL: 6 images
# LAUNDRY_APPLIANCE: 6 images
# SYSTEM_POWER_DEVICE: 6 images
# TENT: 6 images
# FACE_SHAPING_MAKEUP: 6 images
# NOTEBOOK_COMPUTER: 6 images
# PUZZLES: 6 images
# RUG_PAD: 6 images
# BINOCULAR: 6 images
# JUICER: 6 images
# FURNITURE_LINER: 6 images
# TOOTH_CLEANING_AGENT: 6 images
# CHILDRENS_COSTUME: 6 images
# MASSAGER: 5 images
# VEHICLE_LIGHT_BULB: 5 images
# TELEVISION: 5 images
# SKIN_EXFOLIANT: 5 images
# FISHING_EQUIPMENT: 5 images
# TECHNICAL_SPORT_SHOE: 5 images
# THERMOMETER: 5 images
# ICE_CHEST: 5 images
# CHANGING_PAD_COVER: 5 images
# BAKING_CUP: 5 images
# FLASH_DRIVE: 5 images
# GPS_OR_NAVIGATION_SYSTEM: 5 images
# POWER_CONVERTER: 5 images
# COUNTERTOP_OVEN: 5 images
# ABIS_PET_PRODUCTS: 5 images
# FITNESS_BENCH: 5 images
# SKATEBOARD: 5 images
# TOY_BUILDING_BLOCK: 5 images
# MASCARA: 5 images
# TRANSPORT_RACK: 5 images
# REFRIGERATOR: 5 images
# CADDY: 5 images
# GPS_OR_NAVIGATION_ACCESSORY: 5 images
# HAIR_COLORING_AGENT: 4 images
# LITTER_BOX: 4 images
# FIGURINE: 4 images
# ROASTING_PAN: 4 images
# SHEET_PAN: 4 images
# GOLF_CLUB_BAG: 4 images
# PORTABLE_TOOL_BOX: 4 images
# DAIRY_BASED_BUTTER: 4 images
# BREAD_MAKING_MACHINE: 4 images
# TOOTHBRUSH_HOLDER: 4 images
# VACUUM_SEALER_MACHINE: 4 images
# PORTABLE_STOVE: 4 images
# EYEBROW_COLOR: 4 images
# KITCHEN_TOOLS: 4 images
# SLEEPING_BAG: 4 images
# PHONE: 4 images
# RECEIVER_OR_AMPLIFIER: 4 images
# NETWORKING_DEVICE: 4 images
# BODY_LUBRICANT: 4 images
# DIETARY_SUPPLEMENTS: 4 images
# DRINK_COASTER: 4 images
# VEHICLE_LIGHT_ASSEMBLY: 3 images
# BOTTLE_OPENER: 3 images
# CALCULATOR: 3 images
# EARPLUG: 3 images
# AIR_MATTRESS: 3 images
# MANUAL_SHAVING_RAZOR: 3 images
# CURTAIN: 3 images
# NETWORK_INTERFACE_CONTROLLER_ADAPTER: 3 images
# SAW_BLADE: 3 images
# PET_TOY: 3 images
# FUEL_PUMP: 3 images
# PRINTER: 3 images
# ARTIFICIAL_TREE: 3 images
# CAMERA_FLASH: 3 images
# FASTENER_DRIVE_BIT: 3 images
# SPORT_TABLE_GAME: 3 images
# AMAZON_TABLET_ACCESSORY: 3 images
# ELECTRONIC_SWITCH: 3 images
# NON_DAIRY_CREAM: 3 images
# COUNTERTOP_BURNER: 3 images
# HAIR_BRUSH: 3 images
# PERCUSSION_INSTRUMENTS: 3 images
# ABIS_BOOK: 3 images
# DEEP_FRYER: 3 images
# NECKTIE: 2 images
# ROWING_MACHINE: 2 images
# COMPUTER_SPEAKER: 2 images
# UTILITY_CART_WAGON: 2 images
# SPORT_RACKET: 2 images
# AIR_COMPRESSOR: 2 images
# COMPUTER_INPUT_DEVICE_ACCESSORY: 2 images
# VINE: 2 images
# WHEEL_CUTTER: 2 images
# SUGAR_CANDY: 2 images
# ROOM_DIVIDER: 2 images
# WALKING_STICK: 2 images
# SMALL_HOME_APPLIANCES: 2 images
# AIR_FRYER: 2 images
# DISHWASHER: 2 images
# PINBOARD: 2 images
# JERKY: 2 images
# MASSAGE_STICK: 2 images
# SHELLFISH: 2 images
# ABIS_VIDEO_GAMES: 2 images
# BADGE_HOLDER: 2 images
# LEAVENING_AGENT: 2 images
# TABLETOP_GAME: 2 images
# COOKIE_CUTTER: 2 images
# AIR_PUMP: 2 images
# NON_RIDING_TOY_VEHICLE: 2 images
# WALLPAPER: 2 images
# BOXING_GLOVE: 2 images
# VEHICLE_MIRROR: 2 images
# GUITARS: 2 images
# MEDIA_STORAGE: 2 images
# SURVEILANCE_SYSTEMS: 2 images
# ICE_CUBE_TRAY: 2 images
# AUDIO_OR_VIDEO: 2 images
# SLOW_COOKER: 2 images
# KNIFE_BLOCK_SET: 2 images
# DRILL: 1 images
# HOME_ORGANIZERS_AND_STORAGE: 1 images
# WAIST_CINCHER: 1 images
# FLAVORED_DRINK_CONCENTRATE: 1 images
# SCULPTURE: 1 images
# FOOD_DEHYDRATOR: 1 images
# BLANKET: 1 images
# MONITOR: 1 images
# GOLF_CLUB: 1 images
# LEHENGA_CHOLI_SET: 1 images
# AV_RECEIVER: 1 images
# STROLLER: 1 images
# VEHICLE_SCAN_TOOL: 1 images
# SLEEP_MASK: 1 images
# MEMORY_READER: 1 images
# SKIN_TREATMENT_MASK: 1 images
# SHOVEL_SPADE: 1 images
# SUGAR_SUBSTITUTE: 1 images
# TELESCOPE: 1 images
# INFANT_TODDLER_CAR_SEAT: 1 images
# SKIN_FOUNDATION_CONCEALER: 1 images
# SWING: 1 images
# DRINKING_STRAW: 1 images
# THICKENING_AGENT: 1 images
# TIMER: 1 images
# WIRELESS_LOCKED_PHONE: 1 images
# VIDEO_DEVICE: 1 images
# BAKEWARE: 1 images
# VEHICLE_SAFETY_CAMERA: 1 images
# TWO_WAY_RADIO: 1 images
# AGRICULTURAL_SUPPLIES: 1 images
# JEWELRY: 1 images
# NETWORKING_ROUTER: 1 images
# REFRIGERATION_APPLIANCE: 1 images
# OTC_MEDICATION: 1 images
# GARLIC_PRESS: 1 images
# POWERSPORTS_VEHICLE_PART: 1 images
# OUTBUILDING: 1 images
# DINNERWARE: 1 images
# COOKING_OVEN: 1 images
# POWER_BANK: 1 images
# DIGITAL_DEVICE_3: 1 images
# MECHANICAL_LIGHTER: 1 images
# AIR_PURIFIER: 1 images
# SECURITY_CAMERA: 1 images
# CAR_AUDIO_OR_THEATER: 1 images
# COMPUTER_COOLING_DEVICE: 1 images
# TERMINAL_BLOCK: 1 images
# PUNCHING_BAG: 1 images
# COSMETIC_POWDER: 1 images
# BAKING_PAPER: 1 images
# CUTTING_BOARD: 1 images
# BLOOD_PRESSURE_MONITOR: 1 images
# CELLULAR_PHONE: 1 images
# VIVARIUM: 1 images
# GAME_DICE: 1 images
# CONDIMENT: 1 images
# ELECTRONIC_DEVICE_DOCKING_STATION: 1 images
# WRITING_PAPER: 1 images
# HARDWARE_CLAMP_VISE: 1 images
# MATTRESS: 1 images
# SCANNER: 1 images
# LIP_BALM: 1 images
# DEHUMIDIFIER: 1 images
# BABY_BOTTLE: 1 images
# AMAZON_BOOK_READER_ACCESSORY: 1 images
# KICK_SCOOTER: 1 images
# SOUS_VIDE_MACHINE: 1 images

# %%
BASE_PROMPT = """
**Role:** You are an expert AI assistant tasked with generating high-quality data for a Visual Question Answering (VQA) dataset.

**Input:** You will be provided with an image.

**Task:** Analyze the input image thoroughly and generate between 5 and 10 diverse, visually grounded question-answer pairs based *solely* on the image content.

**Strict Constraints:**
1.  **Question Phrasing & Length:** Phrase questions clearly and naturally, like a human would ask. Aim for grammatical completeness while remaining relatively concise (ideally 4-12 words).
2.  **Answer Format:** Each answer MUST be strictly a SINGLE WORD (e.g., 'red', 'car', 'three', 'yes', 'no', 'left', 'running', 'outdoor', 'sunny', 'sign_text_if_one_word'). Do NOT use phrases or sentences. Convert numerical counts to digits (e.g., '3'). Use 'yes' or 'no' for presence questions. Ensure answers are lowercase unless the answer is derived from text in the image (like a proper noun or acronym).
3.  **Quantity:** Generate 5 to 10 unique Q&A pairs.
4.  **Highly Important** Limit yes/no questions to **no more than 2 per image.  
5.  **Formatting for Parsing:**
    *   Place each Question-Answer pair on a **new line**.
    *   Separate the Question from its Answer using the exact separator sequence: ` ### ` (space, hash, hash, hash, space).
    *   **Crucially, do not include this separator sequence anywhere else** in the question or the answer itself.
    *   *Example of correct format:*
        ```
        What color is the main vehicle? ### red
        How many wheels are visible? ### 4
        Is the road wet? ### no
        ```
**Quality & Diversity Guidelines (Crucial):**
*   **Visual Grounding:** Absolutely critical. Both the question and the answer must be directly derivable from visible elements or obvious properties within the image. Do NOT use external knowledge or make complex inferences not explicitly visible.
*   **Answerability & Clarity:** Questions must be unambiguous and have a clear, verifiable single-word answer within the image. If a clear single-word answer isn't possible for a concept, do not ask that question.
*   **Natural Phrasing:** Phrase questions as complete, natural-sounding questions where appropriate, rather than minimal fragments (e.g., prefer 'What color are the leaves?' over just 'Leaf color?'). Ensure the question still logically leads to a single-word answer.
*   **Diversity:** Generate a mix of question types to test different visual understanding skills, *while adhering to the single-word answer constraint*. Aim to include several from this list where applicable and answerable with one word:
    *   **Object Identification**
    *   **Object Presence (Yes/No)**
    *   **Attribute Identification**
    *   **Counting**
    *   **Simple Spatial Relation/Location**
    *   **Scene Type/Setting**
    *   **Simple Action/Activity**
    *   **Text Recognition (OCR)**
"""

# %%
def prepare_prompt_from_image_path(image_path):
    image_path = os.path.abspath(image_path)
    image_filename = os.path.basename(image_path)

    # Get category name from parent directory
    category_dir = os.path.dirname(image_path)
    category_name = os.path.basename(category_dir)
    csv_path = os.path.join(category_dir, f"{category_name}.csv")

    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"Expected CSV file {category_name}.csv not found in: {category_dir}")

    # Load CSV and find row with matching 'path' column
    df = pd.read_csv(csv_path)
    matched_row = df[df['path'].str.endswith(image_filename)]

    if matched_row.empty:
        raise ValueError(f"No matching metadata row found for image: {image_filename}")

    row_data = matched_row.iloc[0]
    metadata_str = " | ".join(f"{col}={row_data[col]}" for col in df.columns if pd.notna(row_data[col]))

    full_prompt = BASE_PROMPT.strip() + f"\n\n**Image Metadata:** {metadata_str}\n\n**Instruction:** Now, analyze the provided image carefully and generate 5-10 Q&A pairs following ALL the above instructions precisely. Use the ` ### ` separator exactly as specified. Ensure questions sound relatively natural and every answer is strictly one word and directly verifiable from the image."

    return full_prompt


def generate_questions_for_image(image_path):
    """
    Generates Q&A pairs from the image using the AI API.
    """
    with open(image_path, 'rb') as f:
        image_bytes = f.read()

    prompt = prepare_prompt_from_image_path(image_path)
    response = client.models.generate_content(
        model='gemini-2.0-flash',
        contents=[
            types.Part.from_bytes(
                data=image_bytes,
                mime_type='image/jpeg',
            ), prompt]
    )
    return response.text



def process_category_images(category_dir, output_csv):
    """
    Processes images in a category directory and generates questions using the AI API.
    Saves results with separate question and answer columns.
    """
    # Check if the output CSV already exists
    if os.path.exists(output_csv):
        df_existing = pd.read_csv(output_csv)
        processed_images = df_existing['image_path'].tolist()
    else:
        df_existing = None
        processed_images = []

    # Get list of all image paths in the category
    image_paths = []
    for subdir, _, files in os.walk(category_dir):
        for file in files:
            if file.endswith(('.jpg', '.jpeg', '.png')):
                image_paths.append(os.path.join(subdir, file))

    # Limit to 4000 images per category
    image_paths = image_paths[:4000]

    # Define column headers
    question_cols = [f"question_{i}" for i in range(1, 11)]
    answer_cols = [f"answer_{i}" for i in range(1, 11)]
    fieldnames = ['image_path'] + question_cols + answer_cols

    # Open CSV for appending
    with open(output_csv, 'a', newline='') as f_out:
        writer = csv.DictWriter(f_out, fieldnames=fieldnames)

        if df_existing is None:
            writer.writeheader()  # Write header only if CSV doesn't exist

        for img_path in tqdm(image_paths, desc=f"Processing {category_dir}", ncols=100):
            if img_path in processed_images:
                continue

            try:
                response_text = generate_questions_for_image(img_path)

                qa_lines = [line.strip() for line in response_text.strip().split('\n') if '###' in line]
                qa_pairs = [line.split(' ### ') for line in qa_lines if len(line.split(' ### ')) == 2]

                row = {'image_path': img_path}
                for i, (q, a) in enumerate(qa_pairs[:10]):  # Max 10 Q&A
                    row[f'question_{i+1}'] = q.strip()
                    row[f'answer_{i+1}'] = a.strip()

                writer.writerow(row)
                time.sleep(4)  # Rate limit

            except Exception as e:
                print(f"Error processing {img_path}: {e}")

# %%
category_dir = '/Users/aryanrastogi/college/vr/vr_major/categorized_data/RING'  # Change this to the category directory
output_csv = '/Users/aryanrastogi/college/vr/vr_major/VR_QA_data3.csv'  # Output file for Q&A data
process_category_images(category_dir, output_csv)
# Out:
# Processing /Users/aryanrastogi/college/vr/vr_major/categorized_data/RING: 100%|█| 122/122 [00:19<00:

# %%
df = pd.read_csv("VR_QA_data2.csv")
df.shape
# Out:
# (1501, 21)

# %%
DESK: 162 images   --DONE
VITAMIN: 152 images  --DONE
COFFEE: 152 images --DONE
COMPUTER_ADD_ON: 151 images  --DONE

BOOT: 125 images  --DONE
ABIS_DRUGSTORE: 123 images  --DONE
CLOCK: 123 images --DONE
RING: 122 images -- DONE
